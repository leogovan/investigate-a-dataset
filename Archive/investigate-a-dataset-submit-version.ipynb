# %% [markdown]
# # Project: An investigation into a TMDB dataset
#
# ## Table of Contents
# <ul>
# <li><a href="#intro">Introduction</a></li>
# <li><a href="#wrangling">Data Wrangling</a></li>
# <li><a href="#eda">Exploratory Data Analysis</a></li>
# <li><a href="#conclusions">Conclusions</a></li>
# </ul>

# %% [markdown]
# <a id='intro'></a>
# ## Introduction
#
# For this project I have chosen to look at the TMDB dataset. This data was provided as part of the Udacity Data Analysis Nanodegree and originated from [Kaggle](https://www.kaggle.com/tmdb/tmdb-movie-metadata). It was originally sourced from IMDB but was replaced after takedown request.
#
# _Questions_:
#
# 1. Which genres are most popular from year to year?
# 1. What kinds of properties are associated with movies that have high revenues?

# %%
import pandas as pd
import numpy as np
% matplotlib inline

import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('darkgrid')
# Stop floats from displaying as scientific notation
pd.options.display.float_format = '{:20,.2f}'.format

# %% [markdown]
# <a id='wrangling'></a>
# ## Data Wrangling
#
# ### General Properties

# %%
# Load your data and print out a few lines. Perform operations to inspect data
# types and look for instances of missing or possibly errant data.
df = pd.read_csv('tmdb-movies.csv')

# %% [markdown]
# #### High level view of the dataset
# ----
# In this section I'll take an initial view of the data - this will also include the number of rows, the datatypes and the number of non-null values in those columns. I'll also take a look at the number of unique values for those columns.

# %%
df.head()
# Out:
#        id    imdb_id           popularity     budget     revenue  \
# 0  135397  tt0369610                32.99  150000000  1513528810
# 1   76341  tt1392190                28.42  150000000   378436354
# 2  262500  tt2908446                13.11  110000000   295238201
# 3  140607  tt2488496                11.17  200000000  2068178225
# 4  168259  tt2820852                 9.34  190000000  1506249360
#
#                  original_title  \
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...
#
#                                             homepage          director  \
# 0                      http://www.jurassicworld.com/   Colin Trevorrow
# 1                        http://www.madmaxmovie.com/     George Miller
# 2     http://www.thedivergentseries.movie/#insurgent  Robert Schwentke
# 3  http://www.starwars.com/films/star-wars-episod...       J.J. Abrams
# 4                           http://www.furious7.com/         James Wan
#
#                          tagline         ...           \
# 0              The park is open.         ...
# 1             What a Lovely Day.         ...
# 2     One Choice Can Destroy You         ...
# 3  Every generation has a story.         ...
# 4            Vengeance Hits Home         ...
#
#                                             overview runtime  \
# 0  Twenty-two years after the events of Jurassic ...     124
# 1  An apocalyptic story set in the furthest reach...     120
# 2  Beatrice Prior must confront her inner demons ...     119
# 3  Thirty years after defeating the Galactic Empi...     136
# 4  Deckard Shaw seeks revenge against Dominic Tor...     137
#
#                                       genres  \
# 0  Action|Adventure|Science Fiction|Thriller
# 1  Action|Adventure|Science Fiction|Thriller
# 2         Adventure|Science Fiction|Thriller
# 3   Action|Adventure|Science Fiction|Fantasy
# 4                      Action|Crime|Thriller
#
#                                 production_companies release_date vote_count  \
# 0  Universal Studios|Amblin Entertainment|Legenda...       6/9/15       5562
# 1  Village Roadshow Pictures|Kennedy Miller Produ...      5/13/15       6185
# 2  Summit Entertainment|Mandeville Films|Red Wago...      3/18/15       2480
# 3          Lucasfilm|Truenorth Productions|Bad Robot     12/15/15       5292
# 4  Universal Pictures|Original Film|Media Rights ...       4/1/15       2947
#
#           vote_average  release_year           budget_adj          revenue_adj
# 0                 6.50          2015       137,999,939.28     1,392,445,892.52
# 1                 7.10          2015       137,999,939.28       348,161,292.49
# 2                 6.30          2015       101,199,955.47       271,619,025.41
# 3                 7.50          2015       183,999,919.04     1,902,723,129.80
# 4                 7.30          2015       174,799,923.09     1,385,748,801.47
#
# [5 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10866 entries, 0 to 10865
# Data columns (total 21 columns):
# id                      10866 non-null int64
# imdb_id                 10856 non-null object
# popularity              10866 non-null float64
# budget                  10866 non-null int64
# revenue                 10866 non-null int64
# original_title          10866 non-null object
# cast                    10790 non-null object
# homepage                2936 non-null object
# director                10822 non-null object
# tagline                 8042 non-null object
# keywords                9373 non-null object
# overview                10862 non-null object
# runtime                 10866 non-null int64
# genres                  10843 non-null object
# production_companies    9836 non-null object
# release_date            10866 non-null object
# vote_count              10866 non-null int64
# vote_average            10866 non-null float64
# release_year            10866 non-null int64
# budget_adj              10866 non-null float64
# revenue_adj             10866 non-null float64
# dtypes: float64(4), int64(6), object(11)
# memory usage: 1.7+ MB

# %% [markdown]
# The next cell was used to sort by different columns names (just replace the column name to get a look at the NaN data or see if there was any 0s).

# %%
df.sort_values(by=['vote_count'], ascending=False)
# Out:
#           id    imdb_id           popularity     budget     revenue  \
# 1919   27205  tt1375666                 9.36  160000000   825500000
# 4361   24428  tt0848228                 7.64  220000000  1519557910
# 1386   19995  tt0499549                 9.43  237000000  2781505847
# 2875     155  tt0468569                 8.47  185000000  1001921825
# 4364   68718  tt1853728                 5.94  100000000   425368238
# 4382   70160  tt1392170                 2.57   75000000   691210692
# 5425   68721  tt1300854                 4.95  200000000  1215439994
# 4363   49026  tt1345836                 6.59  250000000  1081041287
# 629   157336  tt0816692                24.95  165000000   621752480
# 4367   49051  tt0903624                 4.22  250000000  1017003568
# 2410     603  tt0133093                 7.75   63000000   463517383
# 2877    1726  tt0371746                 4.98  140000000   585174222
# 1      76341  tt1392190                28.42  150000000   378436354
# 4365   37724  tt1074638                 5.60  200000000  1108561013
# 2633     120  tt0120737                 8.58   93000000   871368364
# 2409     550  tt0137523                 8.95   63000000   100853753
# 4178     278  tt0111161                 7.19   25000000    28341469
# 4949     122  tt0167260                 7.12   94000000  1118888979
# 630   118340  tt2015381                14.31  170000000   773312399
# 0     135397  tt0369610                32.99  150000000  1513528810
# 4177     680  tt0110912                 8.09    8000000   213928762
# 3     140607  tt2488496                11.17  200000000  2068178225
# 3911     121  tt0167261                 8.10   79000000   926287400
# 3372    1771  tt0458339                 7.96  140000000   370569774
# 7755  Toni Servillo|Denis Fasolo|Nello Mascia|Valeri...
# 7756  Valeria Bertuccelli|Alejandro Urdapilleta|Juli...
# 9575  Ted Vernon|Michael David Simms|Richard Vidan|K...
# 1161  Benedict Samuel|Krysten Ritter|Nick Nolte|Rosa...
# 1154  Reese Witherspoon|Benedict Cumberbatch|Steve C...
# 3724  Denise Richards|Sarah Hyland|Jim Belushi|Kyle ...
# 7760  Daniel BrÃ¼hl|Patrick Kennedy|Vera Farmiga|Joh...
# 6533  Patton Oswalt|Brian Posehn|Maria Bamford|Zach ...
# 7766                                        Daniel Tosh
# 6528  Bono|The Edge|Adam Clayton| Larry Mullen Jr.|G...
# 7768  MichÃ¨le Laroque|Jacques Gamblin|Wladimir Yord...
# 7772  Matthew Wolf|Amy Weber|Shaley Scott|Eliza Swen...
# 3644  Kristy Swanson|Richard Tanne|D. B. Sweeney|Jas...
# 3633  Freida Pinto|Riz Ahmed|Roshan Seth|Kalki Koech...
# 1129  Johan Raja Lawak|Nurul Elfira Loy|Awie|Aznil H...
# 6148  Louise Lasser|Brion James|Paul L. Smith|Sheree...
#
#                                                homepage  \
# 1919              http://inceptionmovie.warnerbros.com/
# 4361                  http://marvel.com/avengers_movie/
# 1386                        http://www.avatarmovie.com/
# 2875       http://thedarkknight.warnerbros.com/dvdsite/
# 4364                         http://unchainedmovie.com/
# 4382                   http://www.thehungergames.movie/
# 5425                         http://marvel.com/ironman3
# 4363                 http://www.thedarkknightrises.com/
# 629                   http://www.interstellarmovie.net/
# 4367                          http://www.thehobbit.com/
# 2410                   http://www.warnerbros.com/matrix
# 2877                       http://www.ironmanmovie.com/
# 1                           http://www.madmaxmovie.com/
# 4365                       http://www.skyfall-movie.com
# 2633                     http://www.lordoftherings.net/
# 2409         http://www.foxmovies.com/movies/fight-club
# 4178                                                NaN
# 4949                      http://www.lordoftherings.net
# 630                         http://marvel.com/guardians
# 0                         http://www.jurassicworld.com/
# 4177                                                NaN
# 3     http://www.starwars.com/films/star-wars-episod...
# 3911                     http://www.lordoftherings.net/
# 3372                  http://captainamerica.marvel.com/
# 1920                       http://www.ironmanmovie.com/
# 6191  http://www2.warnerbros.com/batmanbegins/index....
# 4179                                                NaN
# 1924                          http://www.despicable.me/
# 4370                 http://www.theamazingspiderman.com
# 5432                         http://www.manofsteel.com/
# ...                                                 ...
# 3357                                                NaN
# 3353                                                NaN
# 8829                                                NaN
# 7803                          http://www.onthedoll.com/
# 1093          https://www.facebook.com/CesarChavezMovie
# 3335                     http://www.babybluesmovie.com/
# 3334                                                NaN
# 3330                                                NaN
# 7779                                                NaN
# 7773                                                NaN
# 3772           http://www.bbc.co.uk/programmes/b00zdhtg
# 3596                                                NaN
# 6534                                                NaN
# 7754                  http://www.endofthelinemovie.com/
# 7755                                                NaN
# 7756                  http://www.laantena.ladoblea.com/
# 9575                                                NaN
# 1161                                                NaN
# 1154                                                NaN
# 3724  https://www.facebook.com/pages/Cougars-Inc/172...
# 7760                                                NaN
# 6533                                                NaN
# 7766                                                NaN
# 6528                                      http://u2.com
# 7768                                                NaN
# 7772                                                NaN
# 3644                                                NaN
# 3633                                                NaN
# 1129                                                NaN
# 6148                                                NaN
#
#                                         director  \
# 1919                           Christopher Nolan
# 4361                                 Joss Whedon
# 1386                               James Cameron
# 2875                           Christopher Nolan
# 4364                           Quentin Tarantino
# 4382                                   Gary Ross
# 5425                                 Shane Black
# 4363                           Christopher Nolan
# 629                            Christopher Nolan
# 4367                               Peter Jackson
# 2410              Lilly Wachowski|Lana Wachowski
# 2877                                 Jon Favreau
# 1                                  George Miller
# 4365                                  Sam Mendes
# 2633                               Peter Jackson
# 2409                               David Fincher
# 4178                              Frank Darabont
# 4949                               Peter Jackson
# 630                                   James Gunn
# 0                                Colin Trevorrow
# 4177                           Quentin Tarantino
# 3                                    J.J. Abrams
# 3911                               Peter Jackson
# 3372                                Joe Johnston
# 1920                                 Jon Favreau
# 6191                           Christopher Nolan
# 4179                             Robert Zemeckis
# 1924                  Pierre Coffin|Chris Renaud
# 4370                                   Marc Webb
# 5432                                 Zack Snyder
# ...                                          ...
# 3357                                         NaN
# 3353                           Antoine de Caunes
# 8829                                 Tamra Davis
# 7803                              Thomas Mignone
# 1093                                  Diego Luna
# 3335               Lars Jacobson|Amardeep Kaleka
# 3334                                 Mark Rosman
# 3330                                Mark Hartley
# 7779                                Scott Thomas
# 7773                                   Will Yapp
# 3772  Chris Holt|Stephen Cooter|Michael Lachmann
# 3596                                 Craig Pryce
# 6534                               Jane Anderson
# 7754                           Maurice Devereaux
# 7755                             Andrea Molaioli
# 7756                               Esteban Sapir
# 9575                              William Wesley
# 1161                                Jake Hoffman
# 1154                          Elaine Constantine
# 3724                              K. Asher Levin
# 7760                                 Tom Roberts
# 6533                             Michael Blieden
# 7766                             Manny Rodriguez
# 6528              Hamish Hamilton|Erica Forstadt
# 7768                           Isabelle Mergault
# 7772                                 Leigh Scott
# 3644                                 Griff Furst
# 3633                        Michael Winterbottom
# 1129                                Mamat Khalid
# 6148                                   Sam Raimi
#
#                                                 tagline         ...           \
# 1919               Your mind is the scene of the crime.         ...
# 4361                            Some assembly required.         ...
# 1386                        Enter the World of Pandora.         ...
# 2875                                    Why So Serious?         ...
# 4364        Life, liberty and the pursuit of vengeance.         ...
# 4382                May The Odds Be Ever In Your Favor.         ...
# 5425                Unleash the power behind the armor.         ...
# 4363                                    The Legend Ends         ...
# 629   Mankind was born on Earth. It was never meant ...         ...
# 4367  From the smallest beginnings come the greatest...         ...
# 2410                         Welcome to the Real World.         ...
# 2877                 Heroes aren't born. They're built.         ...
# 1                                    What a Lovely Day.         ...
# 4365                                Think on your sins.         ...
# 2633                          One ring to rule them all         ...
# 2409  How much can you know about yourself if you've...         ...
# 4178  Fear can hold you prisoner. Hope can set you f...         ...
# 4949                    The eye of the enemy is moving.         ...
# 630                         All heroes start somewhere.         ...
# 0                                     The park is open.         ...
# 4177  Just because you are a character doesn't mean ...         ...
# 3                         Every generation has a story.         ...
# 3911                             A New Power Is Rising.         ...
# 3372                        When patriots become heroes         ...
# 1920  It's not the armor that makes the hero, but th...         ...
# 6191                             Evil fears the knight.         ...
# 4179  The world will never be the same, once you've ...         ...
# 1924                                Superbad. Superdad.         ...
# 4370                           The untold story begins.         ...
# 5432               You will believe that a man can fly.         ...
# ...                                                 ...         ...
# 3357                                                NaN         ...
# 3353                                                NaN         ...
# 8829  There's nothing like knowing what you've been ...         ...
# 7803                                                NaN         ...
# 1093                History is made one step at a time.         ...
# 3335                                                NaN         ...
# 3334                                 A modern fairytale         ...
# 3330            The wild, untold story of OZploitation!         ...
# 7779           At 30,000 feet, there's no where to run.         ...
# 7773                                                NaN         ...
# 3772                                                NaN         ...
# 3596                                                NaN         ...
# 6534                                                NaN         ...
# 7754                                                NaN         ...
# 7755                                                NaN         ...
# 7756                          A city without a voice...         ...
# 9575                       Trespassers will be violated         ...
# 1161                                                NaN         ...
# 1154                                                NaN         ...
# 3724     It's 10 p.m. Do you know where your mother is?         ...
# 7760                                                NaN         ...
# 6533                                                NaN         ...
# 7766                                                NaN         ...
# 6528                                                NaN         ...
# 7768                                                NaN         ...
# 7772                                                NaN         ...
# 3644                           Fresh water. Fresh meat.         ...
# 3633                                                NaN         ...
# 1129                     A frog with an identity crisis         ...
# 6148  Extermination is not just a business. It's a w...         ...
#
#                                                overview runtime  \
# 1919  Cobb, a skilled thief who commits corporate es...     148
# 4361  When an unexpected enemy emerges and threatens...     143
# 1386  In the 22nd century, a paraplegic Marine is di...     162
# 2875  Batman raises the stakes in his war on crime. ...     152
# 4364  With the help of a German bounty hunter, a fre...     165
# 4382  Every year in the ruins of what was once North...     142
# 5425  When Tony Stark's world is torn apart by a for...     130
# 4363  Following the death of District Attorney Harve...     165
# 629   Interstellar chronicles the adventures of a gr...     169
# 4367  Bilbo Baggins, a hobbit enjoying his quiet lif...     169
# 2410  Set in the 22nd century, The Matrix tells the ...     136
# 2877  After being held captive in an Afghan cave, bi...     126
# 1     An apocalyptic story set in the furthest reach...     120
# 4365  When Bond's latest assignment goes gravely wro...     143
# 2633  Young hobbit Frodo Baggins, after inheriting a...     178
# 2409  A ticking-time-bomb insomniac and a slippery s...     139
# 4178  Framed in the 1940s for the double murder of h...     142
# 4949  Aragorn is revealed as the heir to the ancient...     201
# 630   Light years from Earth, 26 years after being a...     121
# 0     Twenty-two years after the events of Jurassic ...     124
# 4177  A burger-loving hit man, his philosophical par...     154
# 3     Thirty years after defeating the Galactic Empi...     136
# 3911  Frodo and Sam are trekking to Mordor to destro...     179
# 3372  Predominantly set during World War II, Steve R...     124
# 1920  With the world now aware of his dual life as t...     124
# 6191  Driven by tragedy, billionaire Bruce Wayne ded...     140
# 4179  A man with a low IQ has accomplished great thi...     142
# 1924  In a happy suburban neighbourhood surrounded b...      95
# 4370  Peter Parker is an outcast high schooler was a...     136
# 5432  A young boy learns that he has extraordinary p...     143
# ...                                                 ...     ...
# 3357  One of America's fastest-rising comedians, Bil...      55
# 3353                                 No overview found.     103
# 8829  A woman (Jennifer Jason Leigh) and her son (Bu...     100
# 7803  On The Doll is a story of the victims of child...     102
# 1093  A biography of the civil-rights activist and l...     102
# 3335  On a secluded family farm, a mother suffers a ...      85
# 3334  A reclusive princess and a directionless young...      89
# 3330  As Australian cinema broke through to internat...     103
# 7779  On a flight from Los Angeles to Paris, a mad s...      89
# 7773  A documentary about the making of the controve...      50
# 3772  Who are we? Why are we here? Where do we come ...     240
# 3596  A young witch visits her cousin in a small tow...      85
# 6534  Based on the true story of Evelyn Ryan, a midw...      99
# 7754  Karen, a young psychiatric nurse, boards the l...      95
# 7755  A cop investigates the murder of a beautiful t...      95
# 7756  La Antena (English: The Aerial, 2007) is an Ar...      99
# 9575  Five men heist the Camp Pendleton payroll and ...      83
# 1161  A young musician takes a beautiful tattoo arti...      90
# 1154  2014's best actors pair up in a series of inti...       9
# 3724  When Sam learns his mother cannot afford to se...      81
# 7760  Nazi POWs suspected of heinous acts are locked...     113
# 6533  The Comedians of Comedy is an occasional stand...     103
# 7766  Fresh from his numerous appearances on late ni...      60
# 6528  The DVD features 23 electric performances, wit...     139
# 7768  Anne-Marie vient de perdre son mari dans un ac...      94
# 7772  About a race of alien robots that have conquer...      86
# 3644  Open on gorgeous swamplands of the Atchafalaya...      85
# 3633  Based on Thomas Hardyâ€™s classic novel Tess o...     117
# 1129  A frog who hates the water and jumping wishes ...      88
# 6148  Fed up of his business partner, Ernest Trend h...      83
#
#                                                  genres  \
# 1919  Action|Thriller|Science Fiction|Mystery|Adventure
# 4361                   Science Fiction|Action|Adventure
# 1386           Action|Adventure|Fantasy|Science Fiction
# 2875                        Drama|Action|Crime|Thriller
# 4364                                      Drama|Western
# 4382                  Science Fiction|Adventure|Fantasy
# 5425                   Action|Adventure|Science Fiction
# 4363                        Action|Crime|Drama|Thriller
# 629                     Adventure|Drama|Science Fiction
# 4367                           Adventure|Fantasy|Action
# 2410                             Action|Science Fiction
# 2877                   Action|Science Fiction|Adventure
# 1             Action|Adventure|Science Fiction|Thriller
# 4365                          Action|Adventure|Thriller
# 2633                           Adventure|Fantasy|Action
# 2409                                              Drama
# 4178                                        Drama|Crime
# 4949                           Adventure|Fantasy|Action
# 630                    Action|Science Fiction|Adventure
# 0             Action|Adventure|Science Fiction|Thriller
# 4177                                     Thriller|Crime
# 3              Action|Adventure|Science Fiction|Fantasy
# 3911                           Adventure|Fantasy|Action
# 3372                   Action|Adventure|Science Fiction
# 1920                   Adventure|Action|Science Fiction
# 6191                                 Action|Crime|Drama
# 4179                               Comedy|Drama|Romance
# 1924                            Action|Animation|Family
# 4370                           Action|Adventure|Fantasy
# 5432           Action|Adventure|Fantasy|Science Fiction
# ...                                                 ...
# 3357                                             Comedy
# 3353                                       Comedy|Drama
# 8829                               Comedy|Drama|Romance
# 7803                               Crime|Drama|Thriller
# 1093                                              Drama
# 3335                              Drama|Horror|Thriller
# 3334                                     Fantasy|Family
# 3330                                 Comedy|Documentary
# 7779                                      Horror|Action
# 7773                                        Documentary
# 3772                                        Documentary
# 3596                               Drama|Family|Fantasy
# 6534                                              Drama
# 7754                                    Horror|Thriller
# 7755                                   Mystery|Thriller
# 1154                                                NaN     12/11/14
# 3724             Lookout Films|StoneBrook Entertainment      5/10/11
# 7760                  Thema Production|Peace Arch Films      5/16/07
# 6533                                                NaN       3/1/05
# 7766      Levity Productions|Levity Entertainment Group      6/17/07
# 6528                           Line by Line Productions     11/14/05
# 7768                                            Gaumont      11/1/07
# 7772                                        Asylum, The      6/26/07
# 3644                                       Bullet Films      6/25/11
# 3633      Revolution Films|Head Gear Films|Film i VÃ¤st       9/8/11
# 1129                                        KRU Studios      6/21/14
# 6148  Columbia Pictures Corporation|Renaissance Pict...      9/19/85
#
#      vote_count         vote_average  release_year           budget_adj  \
# 1919       9767                 7.90          2010       160,000,000.00
# 4361       8903                 7.30          2012       208,943,741.90
# 1386       8458                 7.10          2009       240,886,902.89
# 2875       8432                 8.10          2008       187,365,527.25
# 4364       7375                 7.70          2012        94,974,428.14
# 4382       7080                 6.70          2012        71,230,821.10
# 5425       6882                 6.90          2013       187,206,670.55
# 4363       6723                 7.50          2012       237,436,070.34
# 629        6498                 8.00          2014       151,980,023.38
# 4367       6417                 6.90          2012       237,436,070.34
# 2410       6351                 7.80          1999        82,470,329.34
# 2877       6220                 7.30          2008       141,790,128.73
# 1          6185                 7.10          2015       137,999,939.28
# 4365       6137                 6.80          2012       189,948,856.27
# 2633       6079                 7.80          2001       114,528,394.85
# 2409       5923                 8.10          1999        82,470,329.34
# 4178       5754                 8.40          1994        36,777,789.04
# 4949       5636                 7.90          2003       111,423,148.61
# 630        5612                 7.90          2014       156,585,478.63
# 0          5562                 6.50          2015       137,999,939.28
# 4177       5343                 8.10          1994        11,768,892.49
# 3          5292                 7.50          2015       183,999,919.04
# 3911       5114                 7.80          2002        95,768,650.10
# 3372       5025                 6.50          2011       135,715,725.96
# 1920       4920                 6.60          2010       200,000,000.00
# 6191       4914                 7.30          2005       167,484,493.45
# 4179       4856                 8.10          1994        80,911,135.89
# 1924       4851                 7.10          2010        69,000,000.00
# 4370       4837                 6.40          2012       204,195,020.49
# 5432       4729                 6.50          2013       210,607,504.37
# ...         ...                  ...           ...                  ...
# 3357         10                 8.00          2008                 0.00
# 3353         10                 6.00          2008                 0.00
# 8829         10                 6.70          2000                 0.00
# 7803         10                 7.40          2007                 0.00
# 1093         10                 5.30          2014         9,210,910.51
# 3335         10                 4.90          2008                 0.00
# 3334         10                 5.00          2008                 0.00
# 3330         10                 6.40          2008                 0.00
# 7779         10                 5.20          2007                 0.00
# 7773         10                 7.20          2007                 0.00
# 3772         10                 6.60          2011                 0.00
# 3596         10                 6.10          2011                 0.00
# 6534         10                 5.60          2005                 0.00
# 7754         10                 4.20          2007                 0.00
# 7755         10                 5.60          2007                 0.00
# 7756         10                 7.30          2007                 0.00
# 9575         10                 6.00          1988           783,653.68
# 1161         10                 6.50          2014                 0.00
# 1154         10                 6.80          2014                 0.00
# 3724         10                 5.50          2011           969,398.04
# 7760         10                 5.40          2007                 0.00
# 6533         10                 7.00          2005                 0.00
# 7766         10                 6.60          2007                 0.00
# 6528         10                 7.60          2005                 0.00
# 7768         10                 4.60          2007                 0.00
# 7772         10                 1.50          2007                 0.00
# 3644         10                 4.90          2011                 0.00
# 3633         10                 5.30          2011                 0.00
# 1129         10                 3.40          2014                 0.00
# 6148         10                 5.40          1985         6,081,498.16
#
#               revenue_adj
# 1919       825,500,000.00
# 4361     1,443,191,435.21
# 1386     2,827,123,750.41
# 2875     1,014,733,032.48
# 4364       403,991,051.51
# 4382       656,473,401.94
# 5425     1,137,692,372.64
# 4363     1,026,712,780.23
# 629        572,690,645.12
# 4367       965,893,322.82
# 2410       606,768,749.66
# 2877       592,656,630.49
# 1          348,161,292.49
# 4365     1,052,849,482.63
# 2633     1,073,079,785.53
# 2409       132,022,892.45
# 4178        41,693,462.72
# 4949     1,326,278,010.48
# 630        712,291,130.17
# 0        1,392,445,892.52
# 4177       314,713,075.14
# 3        1,902,723,129.80
# 3911     1,122,902,454.42
# 3372       359,229,613.56
# 1920       623,933,331.00
# 6191       417,838,832.58
# 4179       997,333,314.60
# 1924       543,513,985.00
# 4370       714,412,708.53
# 5432       620,445,512.56
# ...                   ...
# 3357                 0.00
# 3353                 0.00
# 8829                 0.00
# 7803                 0.00
# 1093                 0.00
# 3335                 0.00
# 3334                 0.00
# 3330                 0.00
# 7779                 0.00
# 7773                 0.00
# 3772                 0.00
# 3596                 0.00
# 6534                 0.00
# 7754                 0.00
# 7755                 0.00
# 7756                 0.00
# 9575                 0.00
# 1161                 0.00
# 1154                 0.00
# 3724                 0.00
# 7760                 0.00
# 6533                 0.00
# 7766                 0.00
# 6528                 0.00
# 7768                 0.00
# 7772                 0.00
# 3644                 0.00
# 3633                 0.00
# 1129                 0.00
# 6148                 0.00
#
# [10866 rows x 21 columns]

# %% [markdown]
# A view of the number of unique values in the columns:

# %%
df.nunique()
# Out:
# id                      10865
# imdb_id                 10855
# popularity              10814
# budget                    557
# revenue                  4702
# original_title          10571
# cast                    10719
# homepage                 2896
# director                 5067
# tagline                  7997
# keywords                 8804
# overview                10847
# runtime                   247
# genres                   2039
# production_companies     7445
# release_date             5909
# vote_count               1289
# vote_average               72
# release_year               56
# budget_adj               2614
# revenue_adj              4840
# dtype: int64

# %% [markdown]
# #### Confirm ambiguous datatypes
# ----
# A confirmation of the datatypes for all columns described above as 'object'.

# %%
print("I am imdb_id: ", type(df['imdb_id'][0]))
print("I am original_title: ", type(df['original_title'][0]))
print("I am cast: ", type(df['cast'][0]))
print("I am homepage: ", type(df['homepage'][0]))
print("I am director: ", type(df['director'][0]))
print("I am tagline: ", type(df['tagline'][0]))
print("I am keywords: ", type(df['keywords'][0]))
print("I am overview: ", type(df['overview'][0]))
print("I am genres: ", type(df['genres'][0]))
print("I am production_companies: ", type(df['production_companies'][0]))
print("I am release_date: ", type(df['release_date'][0]))
# Out:
# I am imdb_id:  <class 'str'>
# I am original_title:  <class 'str'>
# I am cast:  <class 'str'>
# I am homepage:  <class 'str'>
# I am director:  <class 'str'>
# I am tagline:  <class 'str'>
# I am keywords:  <class 'str'>
# I am overview:  <class 'str'>
# I am genres:  <class 'str'>
# I am production_companies:  <class 'str'>
# I am release_date:  <class 'str'>

# %% [markdown]
# #### Initial thoughts on the data so far
# ---
# _Null Values_
#
# While looking at null rows, I noticed that a number of columns have 0:
# * popularity
# * budget
# * revenue
# * runtime
# * budget_adj
# * revenue_adj
#
# _Uniques_
#
# For columns like 'id' and 'original_title' I would expect these to be unique all the way through. A closer inspection of these rows is needed to decide on the action.
#
# _Datatypes_
#
# On the face of it, the only real issue is with release_date. For proper interogation, this will need converting from a string to a datetime object.

# %% [markdown]
# #### Closer look at the duplications
# ---
#
# This section will look at the several hundred film title dupes and the single ID duplication.

# %%
# create an extra column and mark a row as True where a duplicate itle is found
df['is_duplicate_title'] = df.duplicated(['original_title'])

# %%
# filter anything that is True
df_dupe_title_filter = df[df['is_duplicate_title'] == True]

# %%
df_dupe_title_filter
# Out:
#            id    imdb_id           popularity    budget    revenue  \
# 1133   281778  tt3297792                 0.19         0          0
# 1194   296626  tt3534842                 0.13         0          0
# 1349    42222  tt0076245                 0.40         0          0
# 1440     7445  tt0765010                 1.22  26000000   43318349
# 1513    62320  tt1014762                 0.69         0          0
# 1707    79896  tt1336006                 0.31         0          0
# 1753    36465  tt0992993                 0.25         0          0
# 1757    21398  tt1220213                 0.32   5000000          0
# 1865   220903  tt1533395                 0.10         0          0
# 2036    41505  tt1179069                 0.79  22000000     851517
# 2090    42194  tt0411951                 0.60  30000000     967000
# 2118    33555  tt1522835                 0.51         0          0
# 2227    38568  tt1049402                 0.28     30000     617000
# 2485    26177  tt0207972                 0.55         0          0
# 2489    16716  tt0216621                 0.52         0          0
# 2513     6522  tt0123964                 0.38  80000000   73345029
# 2562    30923  tt0164993                 0.25  21000000          0
# 2571    10047  tt0151137                 0.24  60000000   66976317
# 2695      467  tt0242527                 0.72         0          0
# 2797    11088  tt0252503                 0.27  35000000          0
# 2814    11889  tt0280778                 0.22         0          0
# 2892    88751  tt0373051                 2.00  45000000  101702060
# 2893     8909  tt0493464                 1.98  75000000  258270008
# 3272     7351  tt0903627                 0.28   6000000    1300000
# 3500    64586  tt1588398                 0.85  10000000          0
# 3524    63207  tt1634121                 0.76  13000000          0
# 3636     9364  tt1181614                 0.41   8000000     100915
# 3654    73499  tt1646980                 0.38  17000000    3696232
# 3669    84404  tt1682181                 0.36   1100000          0
# 3738    54320  tt1541874                 0.26    500000          0
# ...       ...        ...                  ...       ...        ...
# 10448    9960  tt0057261                 0.50         0          0
# 10454   29056  tt0057449                 0.25         0          0
# 10460   18331  tt0057372                 0.20         0          0
# 10494    9542  tt0091209                 0.80         0    5844868
# 10517   15392  tt0090888                 0.50         0    5738952
# 10532   24913  tt0090655                 0.39   5000000          0
# 10551   11415  tt0091223                 0.30   3000000          0
# 10555   15698  tt0091875                 0.28         0          0
# 10593   11886  tt0070608                 2.27  15000000   32056467
# 10614    2926  tt0072281                 0.41         0          0
# 10620   15171  tt0070016                 0.36         0          0
# 10625   22307  tt0070698                 0.26    500000          0
# 10628   25473  tt0070895                 0.42         0          0
# 10639   26015  tt0069992                 0.14         0          0
# 10642   16307  tt0070917                 0.40         0          0
# 10644   29425  tt0069895                 0.11    275000          0
# 10678     132  tt0065780                 0.29         0          0
# 10686   51992  tt0065398                 0.08         0          0
# 10691     907  tt0059113                 1.28  14000000  111721910
# 10740   17529  tt0065126                 0.31         0   14250000
# 10757     923  tt0077402                 1.21    650000   55000000
# 10759     948  tt0077651                 1.20    300000   70000000
# 10767   13333  tt0077594                 0.58         0          0
# 10795  148980  tt0077215                 0.21   3000000          0
# 10799   17212  tt0078067                 0.18         0          0
# 10818   39995  tt0079482                 0.05         0          0
# 10827    2661  tt0060153                 0.41   1377800          0
# 10849   28270  tt0060445                 0.21         0          0
# 10853   15598  tt0060086                 0.16         0          0
# 10854   31602  tt0060232                 0.15         0          0
#
#                            original_title  \
# 1133                             Survivor
# 1194                      Finders Keepers
# 1349                                Julia
# 1440                             Brothers
# 1513                                 Home
# 1707                         The Revenant
# 1753                       Into the Storm
# 1757                                Grace
# 1865                                 Life
# 2036                              Shelter
# 2090                               TEKKEN
# 2118                      Sherlock Holmes
# 2227                                 Howl
# 2485                                Annie
# 2489                    A Christmas Carol
# 2513                                 Life
# 2562                  Alice in Wonderland
# 2571                          Joan of Arc
# 2695                             The Hole
# 2797                                Heist
# 2814                                 Iris
# 2892   Journey to the Center of the Earth
# 2893                               Wanted
# 3272                                Julia
# 3500                      Sleeping Beauty
# 3524                            Intruders
# 3636                    Wuthering Heights
# 3654                           The Double
# 3669                                Bully
# 3738                                 Love
# ...                                   ...
# 10448                   Lord of the Flies
# 10454                           The Raven
# 10460                 The Nutty Professor
# 10494                         The Hitcher
# 10517                          Crossroads
# 10532                    April Fool's Day
# 10551                               House
# 10555                      Running Scared
# 10593                          Robin Hood
# 10614                The Three Musketeers
# 10620                     Charlotte's Web
# 10625                             Sisters
# 10628                        Walking Tall
# 10639         Don't Be Afraid of the Dark
# 10642                      The Wicker Man
# 10644                         The Crazies
# 10678                       Gimme Shelter
# 10686               And Soon the Darkness
# 10691                      Doctor Zhivago
# 10740                           True Grit
# 10757                    Dawn of the Dead
# 10759                           Halloween
# 10767                       Game of Death
# 10795                Battlestar Galactica
# 10799                             Patrick
# 10818                        Long Weekend
# 10827                              Batman
# 10849                              Gambit
# 10853                               Alfie
# 10854                           The Chase
#
#                                                     cast  \
# 1133   Danielle Chuchran|Kevin Sorbo|Rocky Myers|Ruby...
# 1194   Jaime Pressly|Kylie Rogers|Tobin Bell|Patrick ...
# 1349   Jane Fonda|Vanessa Redgrave|Jason Robards|Maxi...
# 1440   Tobey Maguire|Jake Gyllenhaal|Natalie Portman|...
# 1513   Glenn Close|Yann Arthus-Bertrand|Jacques Gambl...
# 1707   Chris Wylde|David Anders|Louise Griffiths|Jacy...
# 1753   Brendan Gleeson|Iain Glen|James D'Arcy|Janet M...
# 1757   Jordan Ladd|Samantha Ferris|Gabrielle Rose|Ste...
# 1865                    David Attenborough|Oprah Winfrey
# 2036   Julianne Moore|Jonathan Rhys Meyers|Jeffrey De...
# 2090   Jon Foo|Kelly Overton|Cary-Hiroyuki Tagawa|Ian
# 10827  Adam West|Burt Ward|Cesar Romero|Burgess Mered...
# 10849  Michael Caine|Shirley MacLaine|Herbert Lom|Joh...
# 10853  Michael Caine|Shelley Winters|Millicent Martin...
# 10854  Marlon Brando|Jane Fonda|Robert Redford|E.G. M...
#
#                                                 homepage  \
# 1133   http://www.arrowstormentertainment.com/#!survi...
# 1194                                                 NaN
# 1349                                                 NaN
# 1440                                                 NaN
# 1513                        http://www.homethemovie.org/
# 1707                    http://www.therevenantmovie.com/
# 1753   http://www.hbo.com/movies/into-the-storm/index...
# 1757                                                 NaN
# 1865            http://www.bbc.co.uk/programmes/b00lbpcy
# 2036              http://www.shelter-movie.jp/index.html
# 2090                                                 NaN
# 2118                                                 NaN
# 2227                            http://howlthemovie.com/
# 2485                                                 NaN
# 2489                                                 NaN
# 2513                                                 NaN
# 2562                                                 NaN
# 2571                                                 NaN
# 2695                                                 NaN
# 2797                                                 NaN
# 2814                                                 NaN
# 2892                                                 NaN
# 2893                         http://www.wantedmovie.com/
# 3272                                                 NaN
# 3500                      http://sleepingbeautyfilm.com/
# 3524                                                 NaN
# 3636   http://www.artificial-eye.com/film.php?cinema=...
# 3654                      http://www.thedoublemovie.com/
# 3669                     http://www.thebullyproject.com/
# 3738                http://modlife.com/angelsandairwaves
# ...                                                  ...
# 10448                                                NaN
# 10454                                                NaN
# 10460                                                NaN
# 10494                                                NaN
# 10517                                                NaN
# 10532                                                NaN
# 10551                                                NaN
# 10555                                                NaN
# 10593                                                NaN
# 10614                                                NaN
# 10620                                                NaN
# 10625                                                NaN
# 10628                                                NaN
# 10639                                                NaN
# 10642                                                NaN
# 10644                                                NaN
# 10678                                                NaN
# 10686                                                NaN
# 10691                                                NaN
# 10740                                                NaN
# 10757                                                NaN
# 10759  http://www.theofficialjohncarpenter.com/hallow...
# 10767                                                NaN
# 10795                                                NaN
# 10799                                                NaN
# 10818                                                NaN
# 10827                                                NaN
# 10849                                                NaN
# 10853                                                NaN
# 10854                                                NaN
#
#                                             director  \
# 1133                                       John Lyde
# 1194                                Alexander Yellen
# 1349                                  Fred Zinnemann
# 1440                                    Jim Sheridan
# 1513                            Yann Arthus-Bertrand
# 1707                                 D. Kerry Prior
# 1753                             Thaddeus O'Sullivan
# 1757                                      Paul Solet
# 1865       Martha Holmes|Simon Blakeney|Stephen Lyle
# 2036                     BjÃ¶rn Stein|MÃ¥ns MÃ¥rlind
# 2090                                Dwight H. Little
# 2118                               Rachel Goldenberg
# 2227                    Rob Epstein|Jeffrey Friedman
# 2485                                    Rob Marshall
# 2489                                David Hugh Jones
# 2513                                       Ted Demme
# 2562                                    Nick Willing
# 2571                                      Luc Besson
# 2695                                       Nick Hamm
# 2797                                     David Mamet
# 2814                                    Richard Eyre
# 2892                                     Eric Brevig
# 2893                               Timur Bekmambetov
# 3272                                     Erick Zonca
# 3500                                     Julia Leigh
# 3524                         Juan Carlos Fresnadillo
# 3636                                   Andrea Arnold
# 3654                                  Michael Brandt
# 3669                                      Lee Hirsch
# 3738                                  William Eubank
# ...                                              ...
# 10448                                    Peter Brook
# 10454                                   Roger Corman
# 10460                                    Jerry Lewis
# 10494                                  Robert Harmon
# 10517                                    Walter Hill
# 10532                                    Fred Walton
# 10551                                    Steve Miner
# 10555                                    Peter Hyams
# 10593                            Wolfgang Reitherman
# 10614                                 Richard Lester
# 10620               Charles A. Nichols|Iwao Takamoto
# 10625                                 Brian De Palma
# 10628                                   Phil Karlson
# 10639                                   John Newland
# 10642                                    Robin Hardy
# 10644                               George A. Romero
# 10678  Albert Maysles|Charlotte Zwerin|David Maysles
# 10686                                   Robert Fuest
# 10691                                     David Lean
# 10740                                 Henry Hathaway
# 10757                               George A. Romero
# 10759                                 John Carpenter
# 10767                                  Robert Clouse
# 10795                  Richard A. Colla|Alan J. Levi
# 10799                               Richard Franklin
# 10818                                Colin Eggleston
# 10827                            Leslie H. Martinson
# 10849                                   Ronald Neame
# 10853                                  Lewis Gilbert
# 10854                                    Arthur Penn
#
#                                                  tagline         ...          \
# 1133                             Alone. Stranded. Deadly         ...
# 1194                                                 NaN         ...
# 1349               Through It All, Friendship Prevailed.         ...
# 1440                There are two sides to every family.         ...
# 1513                A Stunning Visual Portrayal of Earth         ...
# 1707   What could be worse than having your best frie...         ...
# 1753                                                 NaN         ...
# 1757                                      Love. Undying.         ...
# 1865                     From the Makers of Planet Earth         ...
# 2036                                     Evil will rise.         ...
# 2090                                 Survival is no game         ...
# 2118   The world's greatest detective has finally met...         ...
# 2227   The Obscenity Trial That Started a Revolution....         ...
# 2485   Disney makes the classical musical more magica...         ...
# 2489                                                 NaN         ...
# 2513                     Share it with someone you love.         ...
# 2562                     A Masterpiece of Imagination...         ...
# 2571                                                 NaN         ...
# 2695                 Once you get in, you can't get out.         ...
# 2797        It isn't love that makes the world go round.         ...
# 2814                                                 NaN         ...
# 2892                       Same Planet. Different World.         ...
# 2893                                Choose your destiny.         ...
# 3272                                                 NaN         ...
# 3500                       Awaken to a World of Wonders!         ...
# 3524                              The Nightmare is Real.         ...
# 3636                          Love is a force of nature.         ...
# 3654                                                 NaN         ...
# 3669                          It's time to take a stand.         ...
# 3738   Have you ever felt alone?...What if you truly ...         ...
# ...                                                  ...         ...
# 10448  Evil is inherent in the human mind, whatever i...         ...
# 10454                 The Macabre Masterpiece of Terror!         ...
# 10460         What does he become? What kind of monster?         ...
# 10494             The terror starts the moment he stops.         ...
# 10517      Where second best never gets a second chance.         ...
# 10532  Childish pranks turn into a bloody battle for ...         ...
# 10551                          Ding dong, Youâ€™re dead.         ...
# 10555                           Two of Chicago's Finest?         ...
# 10593           Meet Robin Hood and his MERRY MENagerie!         ...
# 10614                 . . . One for All and All for Fun!         ...
# 10620  That humble radiant terrific book is now a hum...         ...
# 10625  They were joined at birth by the devil and the...         ...
# 10628  Take your best shot... 'cause it'll probably b...         ...
# 10639                                                NaN         ...
# 10642  Flesh to touch... Flesh to burn! Don't keep th...         ...
# 10644                  All hell is about to break loose.         ...
# 10678  Landmark film follows the Rolling Stones on th...         ...
# 10686  Remember the way Hitchcock kept you on the edg...         ...
# 10691  Turbulent were the times and fiery was the lov...         ...
# 10740          The strangest trio ever to track a killer         ...
# 10757  When there's no more room in hell, the dead wi...         ...
# 10759                            The Night HE Came Home!         ...
# 10767  Bruce Lee challenges the underworld to a Game ...         ...
# 10795  A billion light years from Earth the human rac...         ...
# 10799              He's in a coma... Yet, he can kill...         ...
# 10818  Their crime was against nature. Nature found t...         ...
# 10827           He's Here Big As Life In A Real Bat-Epic         ...
# 10849             Shirley MacLaine raises Michael Caine!         ...
# 10853                 Is any man an Alfie? Ask any girl!         ...
# 10854                                   The chase is on!         ...
#
#       runtime                                          genres  \
# 1133       93                  Science Fiction|Action|Fantasy
# 1194       85                         Mystery|Thriller|Horror
# 1349      117                                           Drama
# 1440      104                              Drama|Thriller|War
# 1513       95                                     Documentary
# 1707      110                                   Comedy|Horror
# 1753      100                           Drama|History|Foreign
# 1757       94                                 Horror|Thriller
# 1865      500                                     Documentary
# 2036      112                         Horror|Mystery|Thriller
# 2090       92     Crime|Drama|Action|Thriller|Science Fiction
# 2118       89            Fantasy|Drama|Horror|Action|Thriller
# 2227       84                                           Drama
# 2485       90                             Music|Family|Comedy
# 2489       95                                   Drama|Fantasy
# 2513      108                              Comedy|Crime|Drama
# 2562      150                                  Fantasy|Family
# 2571      148              Adventure|Drama|Action|History|War
# 2695      102                     Crime|Drama|Horror|Thriller
# 2797      107                     Action|Crime|Drama|Thriller
# 2814       91                                   Drama|Romance
# 2892       93  Action|Science Fiction|Adventure|Comedy|Family
# 2893      110                           Action|Thriller|Crime
# 3272      138                                           Drama
# 3500      102                                   Drama|Romance
# 3524      100                           Horror|Thriller|Drama
# 3636      129                                   Drama|Romance
# 3654       98             Drama|Action|Thriller|Crime|Mystery
# 3669       92                               Drama|Documentary
# 3738       90                           Drama|Science Fiction
# ...       ...                                             ...
# 10448      92                Adventure|Drama|Foreign|Thriller
# 10454      86                           Comedy|Fantasy|Horror
# 10460     107                           Comedy|Romance|Family
# 10494      97                          Horror|Action|Thriller
# 10517      99                     Drama|Music|Mystery|Romance
# 10532      89                         Horror|Mystery|Thriller
# 10551      93                                   Comedy|Horror
# 10555     107                    Thriller|Action|Comedy|Crime
# 10593      83                                Animation|Family
# 10614     105                   Action|Adventure|Comedy|Drama
# 10620      94                          Animation|Drama|Family
# 10625      93                                 Horror|Thriller
# 10628     125                              Action|Crime|Drama
# 10639      74                                 TV Movie|Horror
# 10642      99                         Horror|Thriller|Mystery
# 10644     103                    Action|Drama|Horror|Thriller
# 10678      91                               Documentary|Music
# 10686      99                                Mystery|Thriller
# 10691     197                               Drama|Romance|War
# 10740     128                         Drama|Western|Adventure
# 10757     127                                          Horror
# 10759      91                                 Horror|Thriller
# 10767     103                     Drama|Action|Thriller|Crime
# 10795     125                       Science Fiction|Adventure
# 10799     112                 Horror|Science Fiction|Thriller
# 10818      92                         Horror|Thriller|Mystery
# 10827     105   Family|Adventure|Comedy|Science Fiction|Crime
# 10849     109                             Action|Comedy|Crime
# 10853     114                            Comedy|Drama|Romance
#
#                revenue_adj  is_duplicate_title
# 1133                  0.00                True
# 1194                  0.00                True
# 1349                  0.00                True
# 1440         44,028,788.73                True
# 1513                  0.00                True
# 1707                  0.00                True
# 1753                  0.00                True
# 1757                  0.00                True
# 1865                  0.00                True
# 2036            851,517.00                True
# 2090            967,000.00                True
# 2118                  0.00                True
# 2227            617,000.00                True
# 2485                  0.00                True
# 2489                  0.00                True
# 2513         96,012,519.00                True
# 2562                  0.00                True
# 2571         87,675,538.42                True
# 2695                  0.00                True
# 2797                  0.00                True
# 2814                  0.00                True
# 2892        103,002,487.00                True
# 2893        261,572,412.02                True
# 3272          1,316,622.62                True
# 3500                  0.00                True
# 3524                  0.00                True
# 3636             97,826.80                True
# 3654          3,583,120.07                True
# 3669                  0.00                True
# 3738                  0.00                True
# ...                    ...                 ...
# 10448                 0.00                True
# 10454                 0.00                True
# 10460                 0.00                True
# 10494        11,627,817.87                True
# 10517        11,417,107.90                True
# 10532                 0.00                True
# 10551                 0.00                True
# 10555                 0.00                True
# 10593       157,434,424.97                True
# 10614                 0.00                True
# 10620                 0.00                True
# 10625                 0.00                True
# 10628                 0.00                True
# 10639                 0.00                True
# 10642                 0.00                True
# 10644                 0.00                True
# 10678                 0.00                True
# 10686                 0.00                True
# 10691       773,178,594.14                True
# 10740        84,705,764.87                True
# 10757       183,848,538.22                True
# 10759       233,989,048.64                True
# 10767                 0.00                True
# 10795                 0.00                True
# 10799                 0.00                True
# 10818                 0.00                True
# 10827                 0.00                True
# 10849                 0.00                True
# 10853                 0.00                True
# 10854                 0.00                True
#
# [295 rows x 22 columns]

# %%
# use this cell to spot check titles for differences
df_2 = df[df['original_title'] == 'Robin Hood']
df_2.head()
# Out:
#           id    imdb_id           popularity     budget    revenue  \
# 1938   20662  tt0955308                 2.12  200000000  310669540
# 10593  11886  tt0070608                 2.27   15000000   32056467
#
#       original_title                                               cast  \
# 1938      Robin Hood  Russell Crowe|Cate Blanchett|Mark Strong|Oscar...
# 10593     Robin Hood  Brian Bedford|Phil Harris|Peter Ustinov|Pat Bu...
#
#                                 homepage             director  \
# 1938   http://www.robinhoodthemovie.com/         Ridley Scott
# 10593                                NaN  Wolfgang Reitherman
#
#                                               tagline         ...          \
# 1938   Rise and rise again, until lambs become lions.         ...
# 10593        Meet Robin Hood and his MERRY MENagerie!         ...
#
#       runtime            genres  \
# 1938      140            Action
# 10593      83  Animation|Family
#
#                                     production_companies release_date  \
# 1938   Imagine Entertainment|Universal Pictures|Scott...      5/12/10
# 10593                            Walt Disney Productions      11/8/73
#
#       vote_count         vote_average  release_year           budget_adj  \
# 1938         844                 6.10          2010       200,000,000.00
# 10593        641                 6.90          1973        73,667,393.68
#
#                revenue_adj  is_duplicate_title
# 1938        310,669,540.00               False
# 10593       157,434,424.97                True
#
# [2 rows x 22 columns]

# %% [markdown]
# Upon inspection, it seems that duplicate film titles can be considered different films that have the same name.
#
# The same process is applied for the duplicate ID. Since there is only one duplicate ID, there is no need to create a csv.

# %%
df['is_duplicate_id'] = df.duplicated(['id'])

# %%
df_dupe_id_filter = df[df['is_duplicate_id'] == True]

# %%
df_dupe_id_filter.head()
# Out:
#          id    imdb_id           popularity    budget  revenue original_title  \
# 2090  42194  tt0411951                 0.60  30000000   967000         TEKKEN
#
#                                                    cast homepage  \
# 2090  Jon Foo|Kelly Overton|Cary-Hiroyuki Tagawa|Ian...      NaN
#
#               director              tagline       ...         \
# 2090  Dwight H. Little  Survival is no game       ...
#
#                                            genres    production_companies  \
# 2090  Crime|Drama|Action|Thriller|Science Fiction  Namco|Light Song Films
#
#       release_date vote_count         vote_average release_year  \
# 2090       3/20/10        110                 5.00         2010
#
#                budget_adj          revenue_adj  is_duplicate_title  \
# 2090        30,000,000.00           967,000.00                True
#
#       is_duplicate_id
# 2090             True
#
# [1 rows x 23 columns]

# %% [markdown]
# Now that I have the duplicate ID (and given that the original_title duplicates appear to be different films with the same title), this is a final sense check to make sure the entire row is a duplicate.

# %%
df_3 = df[df['id'] == 42194]
df_3.head()
# Out:
#          id    imdb_id           popularity    budget  revenue original_title  \
# 2089  42194  tt0411951                 0.60  30000000   967000         TEKKEN
# 2090  42194  tt0411951                 0.60  30000000   967000         TEKKEN
#
#                                                    cast homepage  \
# 2089  Jon Foo|Kelly Overton|Cary-Hiroyuki Tagawa|Ian...      NaN
# 2090  Jon Foo|Kelly Overton|Cary-Hiroyuki Tagawa|Ian...      NaN
#
#               director              tagline       ...         \
# 2089  Dwight H. Little  Survival is no game       ...
# 2090  Dwight H. Little  Survival is no game       ...
#
#                                            genres    production_companies  \
# 2089  Crime|Drama|Action|Thriller|Science Fiction  Namco|Light Song Films
# 2090  Crime|Drama|Action|Thriller|Science Fiction  Namco|Light Song Films
#
#       release_date vote_count         vote_average release_year  \
# 2089       3/20/10        110                 5.00         2010
# 2090       3/20/10        110                 5.00         2010
#
#                budget_adj          revenue_adj  is_duplicate_title  \
# 2089        30,000,000.00           967,000.00               False
# 2090        30,000,000.00           967,000.00                True
#
#       is_duplicate_id
# 2089            False
# 2090             True
#
# [2 rows x 23 columns]

# %% [markdown]
# Drop the duplicated ID row from the main dataframe:

# %%
df.drop_duplicates(subset=['id'],inplace=True)

# %% [markdown]
# ### Data Cleaning (Replace this with more specific notes!)

# %%
# After discussing the structure of the data and any problems that need to be
#   cleaned, perform those cleaning steps in the second part of this section.

# %% [markdown]
# #### Drop columns:
# In this section, I've decided to drop columns that are extraneous to the analysis:
# * **imdb_id**: this appears to relate to the previous IMDB data. Assumption is that this was left in by Kaggle to map the IMDB and TMDB ids together
# * **popularity**: I was initially unclear what this measured. After some research on the [TMDB website](https://developers.themoviedb.org/3/getting-started/popularity) it seems that this value is derived from a number of factors and used to assist TMDB's internal search UX e.g. boosting results, etc.
# * **budget** and **revenue**: since budget_adj and revenue_adj have already been normalised to 2010 levels for more direct comparision, these two columns are no longer required
# * **homepage**, **tagline**, **overview** and **keywords**: seem unnecessary to include this for the type of intended analysis
# * **is_duplicate_title**: is no longer necessary
# * **is_duplicate_id**: is no longer necessary

# %%
df.drop(['imdb_id', 'popularity', 'budget', 'revenue', 'homepage', 'tagline', 'overview', 'keywords', 'is_duplicate_title', 'is_duplicate_id'], axis=1, inplace=True)

# %%
df.head(1)
# Out:
#        id  original_title                                               cast  \
# 0  135397  Jurassic World  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
#
#           director  runtime                                     genres  \
# 0  Colin Trevorrow      124  Action|Adventure|Science Fiction|Thriller
#
#                                 production_companies release_date  vote_count  \
# 0  Universal Studios|Amblin Entertainment|Legenda...       6/9/15        5562
#
#           vote_average  release_year           budget_adj          revenue_adj
# 0                 6.50          2015       137,999,939.28     1,392,445,892.52

# %% [markdown]
# #### Update the datatypes
# ---
#
# This section will look to change the release_date from a string to a datetime object.

# %%
df['release_date'] = pd.to_datetime(df['release_date'])

# %%
# check it's worked
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10865 entries, 0 to 10865
# Data columns (total 13 columns):
# id                      10865 non-null int64
# original_title          10865 non-null object
# cast                    10789 non-null object
# director                10821 non-null object
# runtime                 10865 non-null int64
# genres                  10842 non-null object
# production_companies    9835 non-null object
# release_date            10865 non-null datetime64[ns]
# vote_count              10865 non-null int64
# vote_average            10865 non-null float64
# release_year            10865 non-null int64
# budget_adj              10865 non-null float64
# revenue_adj             10865 non-null float64
# dtypes: datetime64[ns](1), float64(3), int64(4), object(5)
# memory usage: 1.2+ MB

# %% [markdown]
# #### Deal with null values
# ---
#
# This section will look to drop rows with null values. For **runtime**, **budget_adj** and **revenue_adj**, 0 values are also considered null.
#
# For the first 'Genres' based question in the introduction, I will look create a dataframe that cleans out null genres, drop extraneous columns and then clean out the 0 values for budget_adj and revenue_adj. This should return me the most number of intact rows suitable for that exploration.
#
# For the question that looks at the types of properties associcated with high revenue movies, I will wish to keep some of the dropped columns for that analysis - therefore, I will use a separate dataframe.

# %%
df_genres = df.copy()
df_genres.drop(['cast', 'director', 'runtime', 'production_companies', 'budget_adj', 'revenue_adj'], axis=1, inplace=True)
df_genres.head(1)
# Out:
#        id  original_title                                     genres  \
# 0  135397  Jurassic World  Action|Adventure|Science Fiction|Thriller
#
#   release_date  vote_count         vote_average  release_year
# 0   2015-06-09        5562                 6.50          2015

# %%
# drop NaN values - only targets genres at this stage
df_genres.dropna(axis=0, how='any', inplace=True)

# %% [markdown]
# Next, I want to:
# * find out the individual genres that are in the genres column; and
# * split these genres out into separate columns for analysis of the first question

# %%
df_genres_split = df_genres['genres'].str[:].str.split('|', expand=True)

# %%
df_genres_split.head(10)
# Out:
#                  0                1                2          3     4
# 0           Action        Adventure  Science Fiction   Thriller  None
# 1           Action        Adventure  Science Fiction   Thriller  None
# 2        Adventure  Science Fiction         Thriller       None  None
# 3           Action        Adventure  Science Fiction    Fantasy  None
# 4           Action            Crime         Thriller       None  None
# 5          Western            Drama        Adventure   Thriller  None
# 6  Science Fiction           Action         Thriller  Adventure  None
# 7            Drama        Adventure  Science Fiction       None  None
# 8           Family        Animation        Adventure     Comedy  None
# 9           Comedy        Animation           Family       None  None

# %%
# 
df_genres_split.groupby(0).count()
# Out:
#                     1     2    3    4
# 0
# Action           1527  1225  624  193
# Adventure         564   486  266  109
# Animation         371   233   92   22
# Comedy           1607   705  154   35
# Crime             377   259   89    9
# Documentary       120    17    2    1
# Drama            1741   866  278   45
# Family            128    69   23    5
# Fantasy           261   217  111   44
# Foreign             8     7    1    1
# History            43    25    8    2
# Horror            662   280   54    5
# Music              77    40   19    3
# Mystery           122    81   29   10
# Romance           177    97   36   11
# Science Fiction   178   115   45    9
# TV Movie           75    58   33   12
# Thriller          398   252   93   18
# War                54    34   15    5
# Western            24    12    8    2

# %%
genres_list = ['Action',
               'Adventure',
               'Animation',
               'Comedy', 
               'Crime', 
               'Documentary', 
               'Drama', 
               'Family', 
               'Fantasy', 
               'Foreign', 
               'History', 
               'Horror', 
               'Music', 
               'Mystery', 
               'Romance', 
               'Science Fiction', 
               'TV Movie', 
               'Thriller', 
               'War', 
               'Western']

count = 0
for i in genres_list:
    boolean_list = []
    genre_index = genres_list[count]
    for row in df_genres['genres']:
        if genre_index in row:
            boolean_list.append(True)
        else:
            boolean_list.append(False)
    df_genres[genres_list[count]] = boolean_list
    count = count + 1

# %%
df_genres.head(1)
# Out:
#        id  original_title                                     genres  \
# 0  135397  Jurassic World  Action|Adventure|Science Fiction|Thriller
#
#   release_date  vote_count         vote_average  release_year  Action  \
# 0   2015-06-09        5562                 6.50          2015    True
#
#    Adventure  Animation   ...     History  Horror  Music  Mystery  Romance  \
# 0       True      False   ...       False   False  False    False    False
#
#    Science Fiction  TV Movie  Thriller    War  Western
# 0             True     False      True  False    False
#
# [1 rows x 27 columns]

# %%
df_genres.drop(['id', 'original_title', 'genres', 'release_date'], axis=1, inplace=True)

# %%
df_genres.head(1)
# Out:
#    vote_count         vote_average  release_year  Action  Adventure  \
# 0        5562                 6.50          2015    True       True
#
#    Animation  Comedy  Crime  Documentary  Drama   ...     History  Horror  \
# 0      False   False  False        False  False   ...       False   False
#
#    Music  Mystery  Romance  Science Fiction  TV Movie  Thriller    War  \
# 0  False    False    False             True     False      True  False
#
#    Western
# 0    False
#
# [1 rows x 23 columns]

# %%
# df_genres_test = df_genres[df_genres.release_year != 2015]
# use this later for dropping specific 0 values from budget_adj

# %% [markdown]
# <a id='eda'></a>
# ## Exploratory Data Analysis
#
# > **Tip**: Now that you've trimmed and cleaned your data, you're ready to move on to exploration. Compute statistics and create visualizations with the goal of addressing the research questions that you posed in the Introduction section. It is recommended that you be systematic with your approach. Look at one variable at a time, and then follow it up by looking at relationships between variables.
#
# ### Research Question 1: Which genres are most popular from year to year?

# %% [markdown]
# In this section we will look to address the question: "Which genres are the most popular from year to year?". To approach this, we need to set some definitions.
#
# **Most popular**: within our cleaned dataset, we have the columns 'vote_count' and 'vote_average'. These two metrics define the number of times a film received a vote by an individual and the average score out of 10 across all the individuals that voted for that film. To define a baseline for popularity, we will look at the average number of votes a film receives AND the vote_average value that is equal to or greater than the 3rd quartile.

# %%
df_genres.describe()
# Out:
#                 vote_count         vote_average         release_year
# count            10,842.00            10,842.00            10,842.00
# mean                217.82                 5.97             2,001.31
# std                 576.18                 0.93                12.81
# min                  10.00                 1.50             1,960.00
# 25%                  17.00                 5.40             1,995.00
# 50%                  38.00                 6.00             2,006.00
# 75%                 146.00                 6.60             2,011.00
# max               9,767.00                 9.20             2,015.00

# %% [markdown]
# As we can see in the cell above, the vote_count has an average of **217.82**, while vote_average has a 3rd quartile of **6.60**. We will use these as our popularity baseline before looking at what are the _most_ popular genres from year to year.

# %%
df_genres = df_genres[df_genres['vote_count'] > 217.82]
df_genres = df_genres[df_genres['vote_average'] > 6.60]
df_genres
# Out:
#        vote_count         vote_average  release_year  Action  Adventure  \
# 1            6185                 7.10          2015    True       True
# 3            5292                 7.50          2015    True       True
# 4            2947                 7.30          2015    True      False
# 5            3929                 7.20          2015   False       True
# 7            4572                 7.60          2015   False       True
# 9            3935                 8.00          2015   False      False
# 12           2854                 7.60          2015   False      False
# 14           4304                 7.40          2015    True       True
# 15           2389                 7.40          2015   False      False
# 17           3779                 7.00          2015    True       True
# 18           1495                 6.80          2015   False      False
# 21           1386                 7.30          2015    True      False
# 24           1545                 7.30          2015   False      False
# 25           2349                 7.10          2015    True      False
# 27           3833                 7.60          2015    True       True
# 28           1559                 7.80          2015   False      False
# 32           1264                 6.80          2015   False      False
# 33           1638                 7.10          2015   False      False
# 35           1520                 8.00          2015   False      False
# 39            754                 7.30          2015   False      False
# 40            918                 7.70          2015   False      False
# 42           1035                 6.90          2015   False      False
# 43           1548                 7.00          2015    True       True
# 44           1221                 7.30          2015   False      False
# 46           1060                 6.90          2015   False      False
# 50            562                 7.10          2015   False      False
# 51           1255                 7.10          2015   False      False
# 52           1172                 6.70          2015   False       True
# 58            867                 7.30          2015   False      False
# 60           1479                 7.10          2015    True      False
# ...           ...                  ...           ...     ...        ...
# 10258         380                 7.00          1993   False      False
# 10398         928                 7.00          1967   False       True
# 10399         426                 7.50          1967   False      False
# 10438         458                 6.70          1963    True       True
# 10439         486                 6.70          1963   False      False
# 10440         434                 7.00          1963   False      False
# 10446         409                 7.50          1963   False       True
# 10472        2027                 7.60          1986    True      False
# 10474         650                 7.30          1986    True      False
# 10476         755                 7.30          1986   False      False
# 10477         792                 7.50          1986   False      False
# 10480         502                 6.90          1986   False      False
# 10486         354                 7.30          1986   False      False
# 10489         347                 6.70          1986    True       True
# 10491         363                 7.00          1986   False      False
# 10492         336                 6.90          1986   False       True
# 10593         641                 6.90          1973   False      False
# 10594        1113                 7.20          1973   False      False
# 10597         279                 7.00          1973    True      False
# 10601         304                 7.70          1973   False      False
# 10648         625                 7.00          1970   False       True
# 10690         620                 7.20          1965   False      False
# 10725         379                 7.00          1969   False      False
# 10755         786                 7.00          1978   False      False
# 10757         306                 7.20          1978   False      False
# 10758         518                 6.70          1978    True       True
# 10759         522                 7.30          1978   False      False
# 10760         230                 6.70          1978   False      False
# 10762         464                 7.40          1978   False      False
# 10820         286                 7.10          1966   False      False
#
#        Animation  Comedy  Crime  Documentary  Drama   ...     History  Horror  \
# 1          False   False  False        False  False   ...       False   False
# 3          False   False  False        False  False   ...       False   False
# 4          False   False   True        False  False   ...       False   False
# 5          False   False  False        False   True   ...       False   False
# 7          False   False  False        False   True   ...       False   False
# 9           True    True  False        False  False   ...       False   False
# 12         False   False  False        False   True   ...       False   False
# 14         False   False  False        False  False   ...       False   False
# 15         False   False   True        False   True   ...       False   False
# 17         False   False  False        False  False   ...       False   False
# 18         False   False  False        False   True   ...       False   False
# 21         False   False  False        False   True   ...       False   False
# 24         False    True  False        False   True   ...       False   False
# 25         False   False  False        False  False   ...       False   False
# 27         False    True   True        False  False   ...       False   False
# 28         False   False  False        False   True   ...        True   False
# 32         False    True  False        False  False   ...       False   False
# 33         False   False  False        False   True   ...       False   False
# 35         False   False  False        False   True   ...       False   False
# 39         False   False  False        False   True   ...       False   False
# 40         False   False  False        False   True   ...       False   False
# 42         False   False  False        False   True   ...        True   False
# 43         False    True  False        False  False   ...       False   False
# 44         False   False  False        False   True   ...       False   False
# 46          True    True  False        False  False   ...       False   False
# 50         False   False  False        False   True   ...       False   False
# 51         False    True  False        False  False   ...       False   False
# 52         False   False  False        False   True   ...       False   False
# 58         False   False  False        False   True   ...       False   False
# 60         False   False   True        False   True   ...       False   False
# ...          ...     ...    ...          ...    ...   ...         ...     ...
# 10258      False   False   True        False   True   ...       False   False
# 10398       True   False  False        False  False   ...       False   False
# 10399      False    True  False        False   True   ...       False   False
# 10438      False   False  False        False  False   ...       False   False
# 10439       True   False  False        False  False   ...       False   False
# 10440      False   False  False        False  False   ...       False    True
# 10446      False   False  False        False   True   ...        True   False
# 10472      False   False  False        False  False   ...       False    True
# 10474      False   False  False        False   True   ...       False   False
# 10476      False    True  False        False   True   ...       False   False
# 10477      False   False   True        False   True   ...       False   False
# 10480      False   False  False        False  False   ...       False    True
# 10486      False   False   True        False   True   ...       False   False
# 10489      False    True  False        False  False   ...       False   False
# 10491      False   False  False        False   True   ...       False   False
# 10492      False   False  False        False  False   ...       False   False
# 10593       True   False  False        False  False   ...       False   False
# 10594      False   False  False        False   True   ...       False    True
# 10597      False   False   True        False  False   ...       False   False
# 10601      False    True   True        False   True   ...       False   False
# 10648       True    True  False        False  False   ...       False   False
# 10690      False   False  False        False   True   ...       False   False
# 10725      False   False   True        False   True   ...        True   False
# 10755      False   False  False        False  False   ...       False   False
# 10757      False   False  False        False  False   ...       False    True
# 10758      False   False  False        False  False   ...       False   False
# 10759      False   False  False        False  False   ...       False    True
# 10760      False    True  False        False  False   ...       False   False
# 10762      False   False  False        False   True   ...       False   False
# 10820       True    True  False        False  False   ...       False   False
#
#        Music  Mystery  Romance  Science Fiction  TV Movie  Thriller    War  \
# 1      False    False    False             True     False      True  False
# 3      False    False    False             True     False     False  False
# 4      False    False    False            False     False      True  False
# 5      False    False    False            False     False      True  False
# 7      False    False    False             True     False     False  False
# 9      False    False    False            False     False     False  False
# 12     False    False    False             True     False     False  False
# 14     False    False    False             True     False     False  False
# 15     False     True    False            False     False     False  False
# 17     False    False    False             True     False     False  False
# 18     False    False     True            False     False     False  False
# 21     False    False    False            False     False     False  False
# 24     False    False    False            False     False     False  False
# 25     False    False    False            False     False     False  False
# 27     False    False    False            False     False     False  False
# 28     False    False    False            False     False      True  False
# 32      True    False    False            False     False     False  False
# 33     False    False    False            False     False      True  False
# 35     False    False    False            False     False      True  False
# 39     False    False     True            False     False     False  False
# 40      True    False    False            False     False     False  False
# 42     False    False    False            False     False     False  False
# 43     False    False    False            False     False     False  False
# 44     False    False     True            False     False     False  False
# 46     False    False    False             True     False     False  False
# 50     False    False     True            False     False     False  False
# 51     False    False    False            False     False     False  False
# 52     False    False    False            False     False     False  False
# 58     False    False    False            False     False     False  False
# 60     False     True    False            False     False      True  False
# ...      ...      ...      ...              ...       ...       ...    ...
# 10258  False    False    False            False     False      True  False
# 10398  False    False    False            False     False     False  False
# 10399  False    False     True            False     False     False  False
# 10438  False    False    False            False     False      True  False
# 10439  False    False    False            False     False     False  False
# 10440  False    False    False            False     False     False  False
# 10446  False    False    False            False     False      True   True
# 10472  False    False    False             True     False      True  False
# 10474  False    False    False            False     False     False   True
# 10476  False    False    False            False     False     False  False
# 10477  False    False    False            False     False     False  False
# 10480  False    False    False             True     False     False  False
# 10486  False     True    False            False     False      True  False
# 10489  False    False    False            False     False     False  False
# 10491  False     True    False            False     False      True  False
# 10492  False    False    False            False     False     False  False
# 10593  False    False    False            False     False     False  False
# 10594  False    False    False            False     False      True  False
# 10597  False    False    False            False     False      True  False
# 10601  False    False    False            False     False     False  False
# 10648  False    False    False            False     False     False  False
# 10690   True    False     True            False     False     False  False
# 10725  False    False    False            False     False     False  False
# 10755   True    False    False            False     False     False  False
# 10757  False    False    False            False     False     False  False
# 10758  False    False    False             True     False     False  False
# 10759  False    False    False            False     False      True  False
# 10760  False    False    False            False     False     False  False
# 10762  False    False    False            False     False     False   True
# 10820  False    False    False            False     False     False  False
#
#        Western
# 1        False
# 3        False
# 4        False
# 5         True
# 7        False
# 9        False
# 12       False
# 14       False
# 15        True
# 17       False
# 18       False
# 21       False
# 24       False
# 25       False
# 27       False
# 28       False
# 32       False
# 33       False
# 35       False
# 39       False
# 40       False
# 42       False
# 43       False
# 44       False
# 46       False
# 50       False
# 51       False
# 52       False
# 58       False
# 60       False
# ...        ...
# 10258    False
# 10398    False
# 10399    False
# 10438    False
# 10439    False
# 10440    False
# 10446    False
# 10472    False
# 10474    False
# 10476    False
# 10477    False
# 10480    False
# 10486    False
# 10489    False
# 10491    False
# 10492    False
# 10593    False
# 10594    False
# 10597    False
# 10601    False
# 10648    False
# 10690    False
# 10725     True
# 10755    False
# 10757    False
# 10758    False
# 10759    False
# 10760    False
# 10762    False
# 10820    False
#
# [799 rows x 23 columns]

# %%
# create action dataframe
df_action = df_genres[df_genres['Action'] == True].copy()
df_action.drop(['Adventure', 
                'Animation', 
                'Comedy',
                'Crime',
                'Documentary', 
                'Drama', 
                'Family', 
                'Fantasy', 
                'Foreign', 
                'History', 
                'Horror', 
                'Music', 
                'Mystery', 
                'Romance', 
                'Science Fiction', 
                'TV Movie', 
                'Thriller', 
                'War', 
                'Western'], axis=1, inplace=True)
df_action.head(1)
# Out:
#    vote_count         vote_average  release_year  Action
# 1        6185                 7.10          2015    True

# %%
# create adventure dataframe
df_adventure = df_genres[df_genres['Adventure'] == True].copy()
df_adventure.drop(['Action', 
                'Animation', 
                'Comedy', 
                'Crime',
                'Documentary', 
                'Drama', 
                'Family', 
                'Fantasy', 
                'Foreign', 
                'History', 
                'Horror', 
                'Music', 
                'Mystery', 
                'Romance', 
                'Science Fiction', 
                'TV Movie', 
                'Thriller', 
                'War', 
                'Western'], axis=1, inplace=True)
df_adventure.head(1)
# Out:
#    vote_count         vote_average  release_year  Adventure
# 1        6185                 7.10          2015       True

# %%
# create animation dataframe
df_animation = df_genres[df_genres['Animation'] == True].copy()
df_animation.drop(['Action', 
                'Adventure', 
                'Comedy', 
                'Crime',
                'Documentary', 
                'Drama', 
                'Family', 
                'Fantasy', 
                'Foreign', 
                'History', 
                'Horror', 
                'Music', 
                'Mystery', 
                'Romance', 
                'Science Fiction', 
                'TV Movie', 
                'Thriller', 
                'War', 
                'Western'], axis=1, inplace=True)
df_animation.head(1)
# Out:
#    vote_count         vote_average  release_year  Animation
# 9        3935                 8.00          2015       True

# %%
# number of times a film is in the 'Crime' genre
df_crime = df_genres[df_genres['Crime'] == True]
crime_counts = df_crime['Crime'].count()
crime_counts
# Out:
# 145

# %% [markdown]
# ### Research Question 2  (Replace this header name!)

# %%
# Continue to explore the data to address your additional research
#   questions. Add more headers as needed if you have more questions to
#   investigate.

# %% [markdown]
# <a id='conclusions'></a>
# ## Conclusions
#
# > **Tip**: Finally, summarize your findings and the results that have been performed. Make sure that you are clear with regards to the limitations of your exploration. If you haven't done any statistical tests, do not imply any statistical conclusions. And make sure you avoid implying causation from correlation!
#
# > **Tip**: Once you are satisfied with your work, you should save a copy of the report in HTML or PDF form via the **File** > **Download as** submenu. Before exporting your report, check over it to make sure that the flow of the report is complete. You should probably remove all of the "Tip" quotes like this one so that the presentation is as tidy as possible. Congratulations!
